# %% [markdown]
# <a href="https://colab.research.google.com/github/gnaneswaryarram/capstoneedx/blob/main/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: read twitter.csv file fro drive

import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/twitter.csv')

# %%
# prompt: Install necessary Python libraries, including TensorFlow, PyTorch, Transformers by Hugging Face

# !pip install tensorflow
# !pip install torch
# !pip install transformers
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)

# %%
# prompt: print above data bye their labels



# Assuming 'label' is the column name for labels
for i in range(len(df)):
    label = df['label'][i]
    text = df['tweet'][i]
    print(f"Label: {label}")
    print(f"Text: {text}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Text: today has been awful but i keep my #headuphigh #positivevibes #bodyposi #goodmood #veryblessed #blessed   #great #feelingood #chawdaddy
#
# Label: 0
# Text: @user he was always ready...  and you never called him :(
#
# Label: 0
# Text: @user he would have washed his color off if he could have.
#
# Label: 0
# Text: awww great...a #text from a #realperson...should i be  ? #nah #meh
#
# Label: 0
# Text:   #humpday favorite #filter #snapchat #smile #latina
#
# Label: 0
# Text: watching this week's @user whilst trying to write repos on a sunday morning has only ended in disaster.   #goodnightahur
#
# Label: 1
# Text: chomsky: israeli #apaheid much worse than south africa   #israel #internationallaw #occupation  #bds
#
# Label: 0
# Text: life is about moments...  happy father's day! âð»ï¸ #gdegblog  #life #moments   #family #selfie #love #igers...
#
# Label: 0
# Text:  craziestpeoples: this is some scary shit..    #motivation
#
# Label: 0
# Text: totally pre ordering #destinyriseofiron as soon as i get paid lol   #hype
#
# Label: 0
# Text: lots of ppl getting the wrong impression of #jocoxmp .not surprised as things will be spin for political gain.
#
# Label: 0
# Text: @user why did you guys change home free so much. first episode everyone knows they get the house for their hero. what's the point now.
#
# Label: 0
# Text: happy friday loversâ¤ï¸ðð¸ð» #love #king #queen #trust #suppo #bff   #friday
#
# Label: 0
# Text:  @user i seriously feel pity for sagarika ..it's difficult to live like this .
#
# Label: 0
# Text: #awkward but   and #whatsup with the #hashtags ð
#
# Label: 0
# Text: stopping off at the @user on our way home today... see if i can find my wedding shoes
#
# Label: 0
# Text: definitely needs that vacation soon..
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text: ben simmons gonna get drafted by the 76ers lmao
#
# Label: 0
# Text: only @user can, #kabali live pics frm woodlands #fans over   #joy #fun #blast #galatta
#
# Label: 0
# Text: negative #emotions have an impoant role to play in a   life; they're big, flashing signs that something needs to #change. #sng
#
# Label: 0
# Text: raymond took @user snapchat  | #logotv #orlando #raymondbraun   #selfie #talk #prayfororlando
#
# Label: 0
# Text: you all think you're his number one   :(
#
# Label: 0
# Text: rainbows follow me everywhere i go ððði must be a unicorn ð¦ð¦ð¦ð¦ #fulloflove
#
# Label: 0
# Text: i am thankful for the sun.#thankful #positive
#
# Label: 0
# Text:  @user pretty well over it.  done with the unnecessary drama, time for living life way it's meant to be lived #carefree   #draâ¦
#
# Label: 0
# Text: why are olives always so hard to open ð  #yummers #olives #tasty #healthier #love #them  â¦
#
# Label: 0
# Text: r.i.p @user you will be dearly missed ð­ð­ð­ðððð #prayforchristina #ripchristina #mayyourheaopen
#
# Label: 0
# Text:  @user be   n #healthy if past history is all there was to the game, the richest people would be librarians. â warren buffâ¦
#
# Label: 0
# Text: i've heard in presidential debates about isis, vladimir putin, and the lgbt rights, but none will address the injustices towards blacks
#
# Label: 0
# Text: food makes me ridiculously happy. i'm having pink lemonade, a hot dog, &amp; a soft pretzel &amp; i'm on cloud 9. it's the little things.
#
# Label: 0
# Text: when you make an offer on the house of your dreams, only to find out someone else made an offer 15 minutes earlier.   #alanismorissette
#
# Label: 0
# Text:  @user he's my king and i'm his queen! ðð #twining #couple   @user
#
# Label: 0
# Text: i am ready. #i_am #positive #affirmation
#
# Label: 0
# Text: wtf!??!ð­ð­why they end #oitnb like that!! ican'teven with these emotions like why kill bae??ð°ð¡   #retaliation hurry up with season5!!!!ð¤
#
# Label: 0
# Text: it was a good day at the gym today. i'm feeling great! :d   #gym #feelinggreat
#
# Label: 0
# Text: twenty yearsð    #hapiness #itsmybihday #mybihday #myday #picturoftheday #picâ¦
#
# Label: 0
# Text:  @user @user how pathetic of @user to attempt to invoke a dead war hero to defend one of many of trump's racistâ¦
#
# Label: 0
# Text: countdown for the company mv appearing soon !!
#
# Label: 0
# Text: @user   bihday# angel â¡â¡â¡â¡â¡â¡
#
# Label: 0
# Text:   #monday !! ...have a #pamper #pay ó¾¥¦ #beauty apps still available ó¾ £ó¾ £ó¾ £ #smoothyou #dalstonsquare...
#
# Label: 0
# Text: blved.. #team #smafrenbec #beloved   #happiness #friends #love
#
# Label: 0
# Text: living through my testimony ðªð¾ #humble #blessed
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text: #buffalo   bull up: you will dominate your bull and you will direct it whatever you want it to do. when you
#
# Label: 0
# Text: we can both have the world!!...â¤ï¸â¤ï¸ðð   #fotoniztas #fashionpose #becauseican #mkb @ kmb
#
# Label: 0
# Text: rise and shine! the #e32016 show floor opens today.   #e3
#
# Label: 0
# Text: here's wishing all the awesome dads a   #fathersday!   don't forget to swing byâ¦
#
# Label: 0
# Text: sometimes, all it takes is a smile #smile     via
#
# Label: 0
# Text: i just really can't with life right now...   #heabroken #scared
#
# Label: 0
# Text: my #eyes don't #lie ... they say " i am   " â¡ ~Â¤ #instapic #instamoment #today #wednesdayâ¦
#
# Label: 0
# Text: _animaladvocate: the "#dairy industry" destroys cows raped &amp; babies stolenð here are   #cows at gentlebarn ð#â¦
#
# Label: 0
# Text: @user #udtapunjab   to watch this movie ð¬ðð
#
# Label: 0
# Text: #podcast   with @user @user @user @user @user @user
#
# Label: 0
# Text: @user @user @user @user @user @user   beauty 2_pearls in silver eyes
#
# Label: 1
# Text: woman in cou on racism charge
#
# Label: 0
# Text: come on england!!!! #euro2016 #engvrus   #nervous ððððâ½ï¸â½ï¸â½ï¸â½ï¸
#
# Label: 0
# Text: last day in the office before #module1   #nervous #fridayfeeling
#
# Label: 0
# Text: black's dark #love #live #wonderful #instame #peace #amo #smile #felicidade #feliz   #kissâ¦
#
# Label: 0
# Text: i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets
#
# Label: 0
# Text:  danky the slob everybody (green shi) has the audacity to say my wife looks like a bulldog. look at this kid...
#
# Label: 0
# Text: god can turn around any situation.  sunday
#
# Label: 0
# Text: yay! third match score i've predicted right in work   #irevswe
#
# Label: 0
# Text: @user so if you paake in this dark skin vs light skin nonsense, you are a by product of this anti-black world
#
# Label: 0
# Text: cooking lesson on-going... then, i want driving lesson...  who wants to train me?  two-wheel driving muna tapos 3, then 4...
#
# Label: 0
# Text: find reasons for living and then #live.   #fathersday #leftside #lookaround
#
# Label: 0
# Text: angry seaside: summer, where are you?   #seaside #summer #summerwhereareyou #where #juneâ¦
#
# Label: 0
# Text: i want hug him
#
# Label: 0
# Text: @user @user @user @user spend this much time on ineptcouncil members clear, oiz, harmon, rather than ð colson
#
# Label: 0
# Text: if ever i hv a bad day i just look @ them...  #summer2016 16 #puppy #dogs_of_instagram  â¦
#
# Label: 0
# Text:   exercise weight loss
#
# Label: 0
# Text:  @user we are   to be #playing at the #openairgalleryberlin #guitarist #violinist #percussionist #openairgallery #obeâ¦ hâ¦
#
# Label: 0
# Text: absolutely disgraceful! this makes me so fucking angry, they are scum and they make me feel ashamed to be english :(
#
# Label: 0
# Text: i clean up pretty good ðð»ð // #latergram #selfie #selfietime #mjbcruise #mjb   #fun #smileâ¦
#
# Label: 0
# Text: my life is perfect right now.   #love #girlswithblondehair #blondehair #girlswithinkâ¦
#
# Label: 0
# Text: be   n #healthy you don't walk into love, you fall in. that's why it's so hard to get out. â unknown
#
# Label: 0
# Text:  , 30 rock, tracy jordan
#
# Label: 1
# Text: @user agreed.. the same is true for  and .. they are overused terms, and as a result, are fast becoming meaningless.. ð¤
#
# Label: 0
# Text: first of my angry bird collection ð  bird birdhat #crochethandmade #crochet.â¦
#
# Label: 0
# Text: the rain paused, the sun warm and @user  &amp; @user giving me #shivers
#
# Label: 0
# Text: it's sad when you make claim you have no legitimate proofs for.
#
# Label: 0
# Text: @user .... you .... you ok?
#
# Label: 0
# Text: @user @user @user imagine commenting on a team(s) you don't even suppo  .
#
# Label: 0
# Text: for me its hard to keep my mind off this slaughter in fl. i try a lot but it always comes back in my head..its like nothin else matters
#
# Label: 0
# Text: unfounate to be more dumb in real life than on the sitcom of yesterday. what would @user say?   #loser
#
# Label: 0
# Text: everything you want is on the other side of fear. #vlicobs #xoxo #love #grace   #amenâ¦
#
# Label: 0
# Text: choose to be happy.  #inspiration  #quote #inspirational
#
# Label: 0
# Text: a good dad is irreplaceable in the lives of his children.   #fathersday #dad
#
# Label: 0
# Text:  @user #flowers  can't solve all problems but they're a great sta   #flower #monday ðð #garden #red #rose
#
# Label: 0
# Text: check this track out!  #background #indie #indierock #audiojungle #royaltyfree #cool #fun #envatomarket   #great
#
# Label: 0
# Text:   birds &amp; bad #piggies #finger family \ #nursery rhymes lyrics and ...  via @user
#
# Label: 0
# Text:  @user obama seems to #numb like he's just going through the motions.   #orlando
#
# Label: 0
# Text: jo cox has died as a result of injuries. may her soul rest in peace.
#
# Label: 0
# Text:   #friday! we look forward to a wonderful weekend here at #luckylinemotors have you made your test drive...
#
# Label: 0
# Text: constitutional law scholar/prof pres. obama calls for cuailing constitutional rights w/o due process.   #wiright #2a #wipolitics
#
# Label: 0
# Text: a young boy shot on his back stray bullet inside the house #corddemos innocent people caught up in this violence!
#
# Label: 0
# Text:  â #sar still trailing the falling eur/jpy rate   #blog #silver #gold #forex
#
# Label: 0
# Text: i am thankful for education. #thankful #positive
#
# Label: 0
# Text: i'm so   and #grateful now that - #affirmations
#
# Label: 0
# Text: can't wait to graduate from my taxidermy degree!
#
# Label: 0
# Text: 100 amazing health benefits of cucumbers!    #healthy is  !!  #altwaystoheal!
#
# Label: 0
# Text: wtf is wrong with florida?!?
#
# Label: 1
# Text: let me tell you a story about  and #videogames. specifically, #marvel super heroes vs. #streetfighter.
#
# Label: 0
# Text: ready to watch @user in lincoln to celebrate mums bihday!!!   #circleoflife
#
# Label: 0
# Text: feeling those plot twist feels ðð #amwriting #valensseries
#
# Label: 0
# Text: no stress in our day. it's #friday. get  .
#
# Label: 0
# Text: when clients bring you presents ððð #chocolate   #galaxychocolate #galaxy @ ms moo make up
#
# Label: 1
# Text: .@user @user ð¹@user so please stop go away &amp; take ur ugly skank @user with u. #pussygrabber
#
# Label: 0
# Text: seriously the luckiest girl on the planet! #ifeel #summerescape   #ineffableglitterâ¦
#
# Label: 0
# Text: i wonder why we bothered moving bk to essex?! no1 eva comes to see us, no1 eva asks me to go out at least in kent i did my own thing!
#
# Label: 0
# Text: when everyone's free when you're in exam mode #wtf #badtiming #guys
#
# Label: 0
# Text: so tonight i met @user now i can #die
#
# Label: 0
# Text: foods for #healing your body!!    #altwaystoheal #healthy is  !!
#
# Label: 0
# Text:   hardcore compilation uk hot teen
#
# Label: 0
# Text: ;you seem to replace, your brain with your hea;  #feminist #beauty #smile   #pride #girlâ¦
#
# Label: 0
# Text: sometimes, all it takes is a smile #smile    via @user
#
# Label: 0
# Text: i don't have to do plexus. i get to do plexus!  #soblessed #grateful
#
# Label: 0
# Text: i am thankful for air conditioning. #thankful #positive
#
# Label: 0
# Text: mazara seems like a good guy. too bad he's on the rangers. another year on this team and he will be a thug. that's what happens to you.
#
# Label: 0
# Text: lebron james is the best 46 minute nba player in the world!  , but true! #nbafinals
#
# Label: 0
# Text: oh damn.. his childhood was so fucked up. he don't know how to be positive reinforcement for his own children
#
# Label: 0
# Text: i love my cats! but sometimes... i really don't like them! #destroyers #mythings   #cats #mine #them #destroy #love #like #notreally
#
# Label: 0
# Text: #translate your documents from #english to #spanish in no time!   customers with every order come and get yours
#
# Label: 0
# Text: pickin crows are playing at tn fitness spa, june 15th, open to the public; 7:00 p.m.   #folkmusic
#
# Label: 0
# Text: very #little is needed to make a   life; it is all within yourself in your way of #thinking.
#
# Label: 0
# Text: #quote of the day:âallow #children to be   in their own way, for what better way will they find?â â samuel...
#
# Label: 0
# Text: last day of summer classes!!ðð
#
# Label: 0
# Text: i am enthusiastic. #i_am #positive #affirmation
#
# Label: 0
# Text: amazing #tunnelview in #yosemite #np #falls #rainbow #father's #day #longexposure #nikon   #obama
#
# Label: 0
# Text: one of the sad moment is when when i couldn't concentrate in my aayat had to close it
#
# Label: 1
# Text: @user #allahsoil not all muslims are islamic extremists (very, very few are).    #emiratisâ¦
#
# Label: 0
# Text:  @user #gehojo  bihday#marilyn monroe #1926-1962
#
# Label: 0
# Text: angry moms be like ð³ #loop #funny #funnyvine  momsbelike #revine  #funnyface
#
# Label: 0
# Text: #home#relax#be #night#girl#alone#psihologija#smile#from#hea# smile to your self and justâ¦
#
# Label: 0
# Text:  @user **** big announcement tonight at 8pm****           set your alarms don't miss it             @user
#
# Label: 0
# Text: #0tolerancemovie, nattaway2 #f4f rss:  nattaway2
#
# Label: 0
# Text: ready for the weekend #miror #selfie #me #follow #me #instafun #instasummer #yass   #readyâ¦
#
# Label: 0
# Text: i'm   @user cause i didn't get a bunt cake... #twitterwarnumber3
#
# Label: 0
# Text: sing along a little goddamn louder #bmth
#
# Label: 0
# Text: my villetta needs some work... #cosplay #anime #makeup
#
# Label: 0
# Text: when people speak of you, it should bring a smile to their face.   #smiles #friends
#
# Label: 0
# Text: last walk on the beach before heading home tomorrow.   #sanibelisland #paradise @ sanibelâ¦
#
# Label: 0
# Text:   bihday to #princephilip - do you like this new official #porait ?
#
# Label: 0
# Text: goodmorning my followers #lovely #addict
#
# Label: 0
# Text:   warns #rahulgandhi not to play politics on #udtapunjab'
#
# Label: 0
# Text: 21 in 29 days cannot wait
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text:   saturday @user @user @user @user @user ! #peace &amp; #love !
#
# Label: 0
# Text: @user @user @user   father's day to  hardworking,  &amp; caring dads &amp; to all single mothers who  play both roles.
#
# Label: 1
# Text: billionaire chair of trump says he hopes obama dies and michelle goes back to being a male ape in africa.  #usa #usa2017 #meltingpot
#
# Label: 0
# Text:  @user cannot wait for a whole week living with @user ð#week #boyfriend  #love #hopehecanputupwithme
#
# Label: 0
# Text: i am so blessed! my girls are perfect!   #mom  #mylife
#
# Label: 0
# Text: in just 5 days time we will be on stand h232! come and see @user for a chat! #hrss16 #cipd #hr
#
# Label: 0
# Text: homemade coleslaw and chicken kiev #foodporn #food #instafood #follow #instacool #foodie  â¦
#
# Label: 0
# Text: its amazing dat d same set of pple who wanted gej's head while he was president hv been giving different offices, yet dey can't perform
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text: #tribeon @user dallas, here we come!!   #talent #musician #model #actress @user
#
# Label: 0
# Text: morning crew cc   #people
#
# Label: 1
# Text: new video shows how  this guy  and how he staed to abuse and humiliated an muslim guyâ¦
#
# Label: 0
# Text: very impressed with @user 's palette. love the highlighters ð @user #makeupblogger   #palette
#
# Label: 0
# Text: @user motherfucker you have 2k tweets in one month. you're not even a real person. and i'm the   one?
#
# Label: 0
# Text: i didnt know @user was still around
#
# Label: 0
# Text: simply the best !!!
#
# Label: 0
# Text:  @user real life living persons actually desire to vote for this vindictive, hate driven, murderous, conniving, liar.
#
# Label: 0
# Text: comfy shoes  #shoes#shoeporn#sneakers#sneakerholics#rubi#comfy#saturday#new #pinoy
#
# Label: 0
# Text: huge black dicks porn   pussy
#
# Label: 0
# Text: healthiness = results ðªð¼ #healthy #fitness   #weightloss #throwback #style #mensstyleâ¦
#
# Label: 0
# Text: i'm singing my blueeeeeeee #blue
#
# Label: 0
# Text: life is good | #whenintagaytay #goodvibes #smile   #me #view #itsmorefuninthephilippines @user
#
# Label: 0
# Text: @user   indeed #ripstephenkeshi
#
# Label: 0
# Text: #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!
#
# Label: 0
# Text: finally got new pandora charms for my bracelet ð
#
# Label: 0
# Text: beach day with bae @user #cocoabeach #summer #florida #life #love   #vibes
#
# Label: 0
# Text:  @user happy matrix anniversary aser! #teammatrix   #mydubai #celebrate anniversary
#
# Label: 0
# Text: my 4y old girl keeps telling everybody at school that today is my bday  awww shes the sweetest ððððððâ¤â¤â¤â¤â¤â¤â¤ #aupairlife
#
# Label: 0
# Text: @user needing your advise #don'tknowwhattodo   #help
#
# Label: 0
# Text: ooooh snap!! dey gettin yall out there too? dayum!!!
#
# Label: 0
# Text: what a great week! kms was awarded again to promote @user in #germany.    #sunnysideoflife
#
# Label: 0
# Text: for real???ð±ð±ð±ð± how legit is this??   sana di hopiað
#
# Label: 0
# Text: we are   to announce the launch of our newly #designed #website which went live now:...
#
# Label: 0
# Text: day off en #cadiz #happiness   #perdonameseÃ±or #perdonameserie #lorenavelarde #picofthedayâ¦
#
# Label: 0
# Text:   father's day to all over the world
#
# Label: 0
# Text:  @user updated. â¤ï¸  #book #wattpad #poetry #verse #poem #poems #smile
#
# Label: 0
# Text:  @user real pleasure to be working with everyone @user on #connecting communities   @user @user
#
# Label: 0
# Text: 1st time #volunteering with @user was an absolutely incredible experience.such generosity,kindness &amp; teamwork.much #love,guys.
#
# Label: 0
# Text: #pray for #orlando. so   this continues to happenððð
#
# Label: 0
# Text: @user i have left school for study leave now ð i only have a couple of exams left ð   #sad #memoriesmatter â¤ï¸â¤ï¸
#
# Label: 0
# Text:   couple having sex bisexual webcam movies
#
# Label: 0
# Text: summer vibes , have a great  weekend #love   #diamonds #gems #rings #fashion #luxury @user
#
# Label: 0
# Text: wow special surprise @user come tokyo dome!! legend wrestler happy
#
# Label: 0
# Text: sooo   to have god in my life...i feel his unwavering &amp; unconditional love every single day!!!  #godsavedme
#
# Label: 0
# Text: having a nice time ðâï¸ð #lovelife
#
# Label: 0
# Text: @user our family is looking forward to visiting #chickfila for the first time, but can't download the app because we're in canada!
#
# Label: 1
# Text: trump ny co-chair makes racist remarks about michelle obama  #p2 #p21 #fyi  #tcot
#
# Label: 1
# Text: @user @user agreed.. the same is true for  and .. they are overused terms, and as a result, are fast becominâ¦
#
# Label: 0
# Text:   fathers day. may you spend the day with the most impoant people in your lives, your family. and, may there be lots of barbecue.
#
# Label: 0
# Text:  @user we are here at the @user for the grand final of the #lct16 good luck @user   #colour #hair #mensimageâ¦
#
# Label: 0
# Text: @user i just posted this on your ig. and with that i am going to bed early.#needabreakfromtoday #peaceð
#
# Label: 1
# Text: #happyholidays and try not to be a  this #christmaseve :-d
#
# Label: 0
# Text: 6 more sleeps until our taster sessions sta ...   #toptots @user @user ððð
#
# Label: 0
# Text:  @user the only person behaving as an idiot would be seen as you @user   &amp; #dumb @user @user
#
# Label: 1
# Text: judge lets  #rapist #johnrkhoward wlk aftr the #rape of a special needs blk teen. ddnt wnt tht on his record, wud nevr work n reverse
#
# Label: 0
# Text: #jackson   polar bear climb racing: angry polar bear climb racing, the polar bear living in cold places look
#
# Label: 0
# Text:  â #eur/usd reverses sharply from monthly high, back below 1.1400 handle   #blog #silver #gold #forex
#
# Label: 0
# Text: 2 days until graduation #gettingserious #almosthere #countdown #proud   #happy then senior week worry begins ð¬ð¬ð¬ð¬
#
# Label: 0
# Text: jump for joy! #chihuahua #dog #puppy #joy   #run #sony #porait #animal
#
# Label: 0
# Text: i want an enchilada and i can't get one tonight and i go to camp tomorrow so it will be at least 5 days until i get one.
#
# Label: 0
# Text: this morning was the best morning! #friends
#
# Label: 0
# Text: anything is possible #disability #positivity #disabled #wheelchair
#
# Label: 0
# Text: get off me it's too late for this smh limelight steal errrr #family #faith #fashion  â¦
#
# Label: 0
# Text: this is so ððððð¼  fathersday #decide  #love #life #success #fatloss #iamgus #wealthâ¦
#
# Label: 0
# Text: its been a long long time #disney #disneyland #childhood #starwars #bb8   #tomorrowland
#
# Label: 0
# Text: i made her close her eyes. she didn't know what we were seeing. #carbonarolive
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text: #good morning  monday
#
# Label: 0
# Text: â­ï¸miss you ðâ¨painting  for them - created by regatte #orlando #prayfororlando  â¦
#
# Label: 0
# Text: enough watching golf for today. tomorrow will be fun. and   fathers day to all my daddy friends. enjoy your day.
#
# Label: 0
# Text: tomorrow first day shoot for #yrkkh ... #newcharacter #starplus   #suzanneberneâ¦
#
# Label: 0
# Text:  @user welcome @user #musicaltheatre #soprano #angel super   2 wrk w u !! #actor #dancer #singer #tv #theatre hâ¦
#
# Label: 0
# Text: see the difference??
#
# Label: 0
# Text:  @user @user  messy church at st.peter's church poesham celebrating its 1st bihday today
#
# Label: 0
# Text: reunion tonight   ð¬@user @user @user @user @user @user @user @user
#
# Label: 0
# Text: now playing  :  david lanz - " cristofori's dream" on    #melancholy   #melancholymusic
#
# Label: 0
# Text: aww yeah it's all good bing bong bing bong
#
# Label: 0
# Text: the console war isn't real, console choices do!   #perplexing
#
# Label: 1
# Text: #people aren't protesting #trump because a #republican won-they do so because trump has fuhered  &amp;â¦
#
# Label: 0
# Text:  @user happy day! âð»ï¸ðªð»ð#cute #toptags #tweegram #amazing #follow4follow #like4like #look #daily  â¦
#
# Label: 0
# Text: @user   poor baby, #lifeoneah
#
# Label: 0
# Text: i didn't make it to this list
#
# Label: 0
# Text:  @user hello twitterworld â¤ summer 2016 â #zeeland #samsung #europe #brouwershaven #grevelingenmeer   #visitholland
#
# Label: 0
# Text:   bihday respected sir
#
# Label: 1
# Text: @user  is still rooted in our society's attitude towards black women's hair. read more from candide uyanze:â¦
#
# Label: 0
# Text: #arianagrandedrawing   attack bull game 3d: do you really think that his head was empty around the city. eac
#
# Label: 0
# Text: afternoon snack âðµð¥ð° #fun   â¦
#
# Label: 0
# Text: it's gotten to the point where spos is more impoant that humans in america.
#
# Label: 1
# Text: homicides rose in most big cities this year - the wall street journal #povey  #inequity #illegalguns
#
# Label: 0
# Text: it truly is the end of an era, love 4 minute and is so sad they are disbanding #4minutepleasestaywithus   #kpop
#
# Label: 0
# Text: and i  can't see you my friend bc i'm so sick ..   ð·ð
#
# Label: 0
# Text: lozza ð¹ð¦âï¸ @user #bestfriend #loveher #holiday #tenerife  â¦
#
# Label: 0
# Text: i ð friday nights!! ð #fridays   #weekend
#
# Label: 0
# Text:  @user although #rain #catsanddogs but i still   for #travel  #tee #ralphlauren  #rawdenim#telagenova #clarksoriginals
#
# Label: 0
# Text:  @user sunny sunday ðððð #maraton #runner #running  #traveler   #zipaquira #bogotadc #colombiaâ¦
#
# Label: 1
# Text: he may be correct. i just can't pay attention to a #communist .
#
# Label: 0
# Text: a week ago today i lost my cat and i found out at this very time 7 days ago. i still have her things.
#
# Label: 0
# Text: i'm so   and #grateful now that - #affirmations
#
# Label: 0
# Text: #healthandfitness   attack bull game 3d: do you really think that his head was empty around the city. each s
#
# Label: 0
# Text:   &amp; #grateful that #money comes to me in #increasing quantities from #multiple sources on a #continuous basis
#
# Label: 0
# Text: #lucky   #dad to be cared loved by #amazing #loving #caring #daughter #jannarden! wishingalldadsgoodgirlsboys!â¥
#
# Label: 0
# Text:  #anmolshare: "  #fathersday!  gift your #dad a secured #financial #future! #save #insureâ¦
#
# Label: 0
# Text:   father's day to all the proud fathers in the world! long life and prosperity.
#
# Label: 1
# Text: #sikh #temple vandalised in in #calgary, #wso condemns  act
#
# Label: 0
# Text: @user fantastic prize !!!!!!!!!!!!!!   #familytreat #winitwednesday
#
# Label: 0
# Text: @user   bihday looking beautiful as always ....when 35 is the new 21
#
# Label: 0
# Text: itâs amazing how true this is! #healthyeating #eathealthy
#
# Label: 0
# Text: take me back ... or not? ððð #tb #throwback #seoul #korea #holiday #love   #gloww #asiaâ¦
#
# Label: 0
# Text: donât ask sad people how to be  .
#
# Label: 0
# Text: check  let us not forget our heavenly father,   father's day too papa #jesus! ðð¼ð   @user
#
# Label: 0
# Text: @user   @user throws up a paicularly destructive l as she sneers "loser"
#
# Label: 0
# Text: happy father's day dad! #abc7chicago   #fathers #day #celebration
#
# Label: 0
# Text: i cannot wait to visit pittsburgh ð§ðºð¸ðâï¸â¤ï¸
#
# Label: 0
# Text:   friday! #ff our breakroom panel: @user @user @user talking teen paies, #trump dating and #guns.
#
# Label: 0
# Text: hope you all are having a lovely #sunday âï¸   #fathersday to all the #dads out there! #photo...
#
# Label: 0
# Text:   hillary clinton shifts and says she is "happy" to use the term "radical islam": washington (cbs news) ...
#
# Label: 0
# Text:   @user - movies &amp; booze make long flights fun but also make jetlag worse.  high-five to beating jet lag
#
# Label: 0
# Text: #meditation   gorilla simulator: you need to do to adapt to the environment. the need to tear the city. mate
#
# Label: 0
# Text: from our pastor. join us tomorrow at libey city church of christ. morning worship 10am, afternoon worship 5pm.
#
# Label: 0
# Text: it's friday tmrw and there's no new episode of greys to watch.
#
# Label: 0
# Text: i cannot wait to go see finding dory! ðððð  #findingdory #cantwait
#
# Label: 0
# Text: hooray! have been selected to #review an #oralb #toothbrush! ðð   #wonderwhatone #reviewer
#
# Label: 0
# Text: this looks like the night shift at your local #newjersey diner. #spiceworld
#
# Label: 0
# Text: i dont know why bad thing happend   #bad #moment #hate #life #not_lol
#
# Label: 0
# Text: rain or shine. ..this treasure hunt is gonna go down!! #ottawagiveaway
#
# Label: 0
# Text:  @user any man can be a father, but it takes a special person to be a dad   #father's #day
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text:  @user @user end times... i'm staing to wonder if god has totally turned his back on america.. this is sickening...   @user
#
# Label: 0
# Text: i pray the lord either saves the westboro baptist church with the true gospel, or crushes them for the sake of the true gospel.
#
# Label: 0
# Text: #tuesdaymotivation the truth about being   or $ back. #success  â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦ â¦
#
# Label: 0
# Text: thunderball - thunderdance (1994)  #cd   hardcore #oldschool techno #vk download here:
#
# Label: 0
# Text: stoked to go camping ð»ð #camping
#
# Label: 0
# Text: decided to get jeff and i tickets for the new tules movie tonight. ð
#
# Label: 0
# Text: an positive quote to have a nice thursday: life is like a mirror if you smile at it it smiles back :)
#
# Label: 0
# Text: @user they don't want to label the place a "gay club" for staers...as trump would say,
#
# Label: 0
# Text: i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets
#
# Label: 0
# Text: #solid #set if i may say so myself. that was #fun ... and im still   #needinesslevel 6.3 #standupcomedy
#
# Label: 1
# Text: #people aren't protesting #trump because a #republican won-they do so because trump has fuhered  &amp;â¦
#
# Label: 0
# Text: here's your feel-good story for the day. &lt;3    #love #dogs #kids
#
# Label: 0
# Text:   &amp; #grateful that #money comes to me in #increasing quantities from #multiple sources on a #continuous basis
#
# Label: 0
# Text: sometimes i just gotta list it out ð   #inthesunshine
#
# Label: 0
# Text:  @user sacred #piano #musicproducer #musicproduction #electronic #electricmusic #aist #music  â¦
#
# Label: 0
# Text: seriously what is going on with 2016?
#
# Label: 0
# Text: food with friends. #food #life   #friends
#
# Label: 0
# Text:  @user so annoyed i didn't get this hoodie from @user when i tried it on and now i can't find any xs anywhere
#
# Label: 0
# Text: @user @user congratulations for making ghana proud... you are our black star. more love,   daddies day #sark
#
# Label: 0
# Text: being #successful and   as a mom, professional and grad student is enough to show women rock! #likeagirl
#
# Label: 0
# Text: @user 140 days to go ððð   #concecountdown ððððð
#
# Label: 0
# Text:  @user cleaning the apament before getting a friend over from finland today! =)
#
# Label: 0
# Text: how's the serenity?!? pure #magic top of #mtbaldy   #hikingadventures @ mount baldy 10,064 ft
#
# Label: 0
# Text: you hate blacks enjoying being black, @user ie. miscegenation.   @user @user @user @user
#
# Label: 0
# Text:   saturday @user @user @user  @user @user &lt;== #listen to their music #follow them #sigam-nos !
#
# Label: 0
# Text: âthe worst pa of success is trying to find someone who is happy for youâ -bette midler #quote #handmade   #success
#
# Label: 0
# Text: oh my god ð­ð© poor baby
#
# Label: 0
# Text: @user    bird #okweworkofficehouse  #watchmkwork  #delatejpayas #groupononwin #openepx #greegewekaziquee
#
# Label: 0
# Text: when you lose a snap streak of 140 days..   #crying #how
#
# Label: 0
# Text: wishing my lovely dad a very  fathersday - love you millions! &amp; i hope you like you present! ðððâ³ï¸ðâ¤ï¸ððð #fathersday #lovetoall
#
# Label: 1
# Text: just like , #waronwomen, &amp; #guncontrol @user need #russia to be the bad guy as an excuse for their bad ideology #tlot #p2
#
# Label: 0
# Text: summer is only a week away! #summer2016 #chinup #summer   #countdown
#
# Label: 0
# Text: #imwithher? hillary clinton took money from islamic countries and remains silent on treatment of muslim women!
#
# Label: 0
# Text: begginer.... ððð  #ilovea #ilovepaint #mayma #enjoy   #paint #instaa #instaloveâ¦
#
# Label: 0
# Text: only spared the embarrassment of being closed out in game 5 by #nba league manipulation.
#
# Label: 0
# Text: got our tickets for #findingdory!!! ðâ¤ï¸ #findingnemo #movie #premier #ellen   #excitingâ¦
#
# Label: 0
# Text: everything i've seen about this game so far makes me feel like they're doing things right. can't wait
#
# Label: 1
# Text: @user @user we need to â these universities from indoctrinating our children turning them to #idiots &amp; #snowflakes &amp;
#
# Label: 0
# Text: i wanna go shootin w.my bro in ut, when i go back next mth.
#
# Label: 0
# Text: links from twitter used to be free ð£
#
# Label: 0
# Text: now playing  :  lee blaske - " 15 - through the mirror - pa 2" on    #melancholy   #melancholymusic
#
# Label: 0
# Text: @user @user @user come back to corset talk in my mentions.    i got a very cheap one off ebay. costume. ~
#
# Label: 0
# Text: getting to know our acts: @user is on sunday at 1.15pm/2.15pm/4pm/ and 5.15pm...only 18 days to go!
#
# Label: 0
# Text: @user why is the crew between takes denying an old man carrying groceries home from crossing the street?
#
# Label: 0
# Text: ready to sta my new job!   iew i dont use hashtags wtf
#
# Label: 0
# Text: hobi's face looks like 'omg, this is a disgusting experience'
#
# Label: 1
# Text: are you #black &amp; feel like the  are stomping on you? â¦  #retweet #tampa #miamiâ¦
#
# Label: 0
# Text:  @user how to get hyped: remember @user tour in november   w/ @user
#
# Label: 0
# Text: ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦
#
# Label: 0
# Text: so   i have the #beach  here on days like these just roll around in the sand like a bum and get wet!
#
# Label: 0
# Text: for the first time â²*ï¾   day #thankyou #ooyama #firsttime #eyelashes #miq #ðâ¤ï¸  #ããã¨ã¯â¦
#
# Label: 0
# Text: now playing  :  alexandre desplat - " river waltz (piano solo)" on     music song
#
# Label: 0
# Text: great qualy for both @user and i, pole position for the @user #bentley! great job by all at @user  !!!
#
# Label: 0
# Text: #payintheusa   polar bear climb racing: angry polar bear climb racing, the polar bear living in cold place
#
# Label: 0
# Text: tomorrow is my bihday   bihday shaterirunnels
#
# Label: 0
# Text: this is shoking and it isnt fair #ripchristinagrimmie #greatvoice #awesomesinger   #shoking
#
# Label: 0
# Text:  @user two of my favourite people #wedding #hendersons   #love @ heskin hall
#
# Label: 0
# Text: selamat malam ð¹  #after#youth#worship  #sunday #full#blessed
#
# Label: 0
# Text: be sma and sexy &lt;3   #alicrytrinkets #beautiful   #thegoodlifeâ¦
#
# Label: 0
# Text: #tattoosleeves   gorilla simulator: you need to do to adapt to the environment. the need to tear the city. m
#
# Label: 0
# Text: this little guy was too cute today ð   #travel #pet #pets #nature #cute   #dog #dogs #catâ¦
#
# Label: 0
# Text: disneyð­ð°ð¸ðã2ã  #disneyland  #enjoy    #å¶æ
#
# Label: 0
# Text:   new year from #ukraine!
#
# Label: 0
# Text: @user @user mr. paris dinnard...is in denial... smh
#
# Label: 0
# Text: @user @user me too she said a way to follow her.by some other name but i didn't :(   she is proly doing good n lookin good
#
# Label: 0
# Text: @user when will you announce the next production?   :)
#
# Label: 1
# Text: #history will not be kind to those who enable the #corruption,  and #misogny of @user and his embâ¦
#
# Label: 0
# Text: when your campers decide to work at camp!   #imold
#
# Label: 0
# Text: i am inventive. #i_am #positive #affirmation
#
# Label: 0
# Text: bard  marocan teapot  designed by elhabiba #maroc#design#a#tourisme #love#amsterdam#paris#londen#italy
#
# Label: 0
# Text: helping kids cope with   feelings: workbook for #home, #school and #counseling
#
# Label: 0
# Text:   #bihday #later for my #lovely sis #love #chocolate #our #favorite #cake #mochaâ¦
#
# Label: 1
# Text: @user #allahsoil people around the world are afraid. the world is primed to react.  â¦   #emiratis #2â¦
#
# Label: 0
# Text:  @user industrial waste in ganges is less harmful than a hindu having a dip in ganges is the sickular libral logic.  n sorry 4â¦
#
# Label: 0
# Text: happy visitors @user #customers   #mahome #pillows #marioaavia #costarica #home #decoration #textil
#
# Label: 0
# Text: #orlando can't get a break
#
# Label: 0
# Text: monica and tessa is happy since she is blowing hard! on facebook: #tessa #monica #since   #blowing
#
# Label: 0
# Text: at gymðª.... things that happenâ...   day #gym #gymtime #goodvibe #love #peace #energyâ¦
#
# Label: 0
# Text:  @user #fashion it is a true   #fact
#
# Label: 0
# Text:  @user thanks @user the #autism film plans are hotting up  ! your &amp; andrew's hard work is coming together xx @user
#
# Label: 0
# Text: check  @user - the #kids will be   to see you back too!   @user
#
# Label: 0
# Text: i am thankful for my best friends. #thankful #positive
#
# Label: 0
# Text: orlando, fl has taken so many l's this week
#
# Label: 0
# Text: anyone who says sunshine brings happiness has never danced in the rain. #dancing   #neoballet
#
# Label: 0
# Text: #me   now or never -
#
# Label: 0
# Text: they'll never understand ^^ . . #perfect_sad_boy   #boy #love #k #korean #kpop #arab_exoticâ¦
#
# Label: 0
# Text: as a leader someone is always watching i gotta always keep it real with myself first-#me first me first  monday yall
#
# Label: 0
# Text: how to get hyped: remember @user tour in november   w/ @user
#
# Label: 0
# Text: if that brock rapist wasn't a spoiled white kid his ass would've gotten 60 years #merica
#
# Label: 0
# Text: be   and #stressfree! #free intro to #vedic #meditation on sunday july 10, 4-5:30pm at 1848 w 18th st, in #chicago #chicagomeditation
#
# Label: 1
# Text: @user the real jeff sessions.   #neverump #swampmonster  #
#
# Label: 0
# Text: exciting stuff happening!   #kareoke #havingfun #lol thank god the music was loud cause i'm a terrible singerðð
#
# Label: 0
# Text:  @user chill relaxing piano music to keep your pet #quiet and   during #july4th #fireworks  â¦ â¦
#
# Label: 0
# Text:   bihday to this man with great #humour
#
# Label: 0
# Text: awww yes i love it ðð
#
# Label: 0
# Text: #im#so  #about #somethinðð»ðð»ð¯ð¯ðð»ðð»âð½ð
#
# Label: 0
# Text: show some compassion @user @user
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text: hard-core gamer goes mental playing bo3
#
# Label: 0
# Text: im kind of miserable and it feels permanent but it's whatever.   #grunge #quotes #depressed
#
# Label: 0
# Text:  livelypics: loving someone and being loved in return makes wounds heal faster, due to the release of oxytocin in the blood.   #motivaâ¦
#
# Label: 0
# Text:  @user there are no flying #elephants ! i'm #butterfly ...ðððð   ð
#
# Label: 0
# Text: love this #tshi #pokemon #nintendoe3 #e32016 for #men and #women #hypebeast #youthday2016 #thursdaythoughts #gift
#
# Label: 0
# Text: runway lights almost brighter than sunset now ð§ #goinghome   #ibiza
#
# Label: 0
# Text:    #90th bihday to #her #majesty the #queen, queen elizabeth
#
# Label: 0
# Text: #germanyhetalia   bull up: you will dominate your bull and you will direct it whatever you want it to do. wh
#
# Label: 0
# Text: my jogging along the waterfront ðð»ðªð»ð adorable! ððð #vietnam #nhatrang   #run #awesomeâ¦
#
# Label: 0
# Text: life is a story, and this is my history ðð . . . #asistenapoteker #fun #smiles   ladyâ¦
#
# Label: 0
# Text: ak420 friendly media (550 cr adveising) doing all effos to suppo diy game of ak420.  shame paki gangsters.
#
# Label: 0
# Text: @user thank you!  #wednesday
#
# Label: 0
# Text: omg. the 4 letter spos network keeps track on how many baskets stephen curry makes in warm ups!
#
# Label: 0
# Text:  @user #harrystyles #onedirection #1dfana   #1d i love harry with all my hea:) @user be happy, my dear:)))
#
# Label: 0
# Text:   word #chalka at #temeculaafestival #chalkfest in #oldtowntemecula #temecula #inspirationala
#
# Label: 0
# Text: god please see me through in this hard times that i am currently facing...   #tdigcomms
#
# Label: 0
# Text: relaxing because my weekend is about to get busy!
#
# Label: 0
# Text:   father's day  #love #you #guys  #saba#â¤ï¸  #hamed @ newpoâ¦
#
# Label: 0
# Text: when you're hungry af &amp; tired af at the same time so you have no ambition to go get foodð­ð­ð­ð­
#
# Label: 0
# Text: it feels good to be lost in the right direction - enjoy your #walk :)  happy friday   #no9to5 #enjoy   #friday
#
# Label: 0
# Text:  @user tiny crown #floral #photography, an #image 2 b   by! #imagine  @user @user #aforall
#
# Label: 0
# Text: when you broke and broken. can't even see the bestie.   @user
#
# Label: 0
# Text: what you gonna do?
#
# Label: 0
# Text:  @user its my bihdayâ¼ï¸ð¤ð½ð  bihday to meðð¾
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text:  @user being   never goes out of style! :)
#
# Label: 0
# Text:  @user how do you make a kleenex dance? ... put a little boogie in it! #dadjokes   #fathersday #wonderfulwakey
#
# Label: 0
# Text: inspired mornings, hustle hard for what you want!! #beauty #beautiful   #motivationâ¦
#
# Label: 0
# Text:  @user i am thankful for good nightsâ sleep. #thankful #positive
#
# Label: 0
# Text:  @user will do another show in december in anaheim ! stay tuned ! @user
#
# Label: 0
# Text: a nice way to wake up in the morning :) #dog   #cute  #petsofinstagram @user
#
# Label: 0
# Text: @user oh my gooooodddddddddddddd â¤ï¸â¤ï¸â¤ï¸â¤ï¸   #celinedion â¤ï¸â¤ï¸â¤ï¸
#
# Label: 1
# Text: @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user
#
# Label: 1
# Text: @user @user @user #popefrancis called out  #xenophobic #trump so why would @user #catholicchurch #suppo
#
# Label: 0
# Text: go like and subscribe trying to get this out there !! #youtube #hairbundles #hair
#
# Label: 0
# Text: don't ever be #afraid to show who you #really are, because as long as you are   with yourself no one...
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 1
# Text: awesome. black man gets kkk members to disavow by befriending them   #blacklivesmatter
#
# Label: 0
# Text:   #fathersday #dad @user
#
# Label: 0
# Text: now playing  :  fariborz lachini - " soghat (solo piano)" on     music song
#
# Label: 1
# Text: lol these pasty cakes telling the #rockette to quit b/c of her choice  not to suppo your  asshat president is pure comedy. weirdos
#
# Label: 0
# Text: #costacupping day #171 - i don't have kids. but this little one is like my daughter.   #fathersday to all...
#
# Label: 0
# Text: come and get it!! #2008 #ford #mustang #usedcars #houston #texas #suv #mustangcoupe #sale   #thursday
#
# Label: 0
# Text: i'm   for the #weekend and i will #sing to my #hea's content
#
# Label: 0
# Text: friends forever   #saturday #mylove #mcdonald #coffeetime #hotoutside #metroÅwiÄtokrzyskaâ¦
#
# Label: 0
# Text: @user dat true wit nothing bt uyindoda  farhers day
#
# Label: 0
# Text: the best kids bihday pay entrance ever?? #spiderman #bihday  ! #spiderdad
#
# Label: 0
# Text: pens fans are
#
# Label: 0
# Text: my baby is in the best mood this morningð #baby #sister   #playful #love
#
# Label: 0
# Text: when sisters love their friends more than their own siblings.
#
# Label: 0
# Text: boasty tuesday last night....
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text: president mahama, sadly, lost his dear mum last night. my condolences to him and the bereaved family.
#
# Label: 0
# Text:  @user this about something that makes you happy for 5 seconds. retrain your #brain for #happiness
#
# Label: 0
# Text: enjoy your weekend! #weekend #friday   #teacher #teach #school #relax
#
# Label: 0
# Text: brookelle bones longporn   hardcore compilation
#
# Label: 0
# Text: sunday mood . ð·allanxreyes  . #sundays #moods   #weekend #love #fashionphotographyâ¦
#
# Label: 0
# Text: ð â½ï¸ ð ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme  â¦
#
# Label: 0
# Text: it doesn't look like, i'm going to sta on my #marsterdegree  this summer.. :(    so now i'm #lookingforajob !   wish me #goodluck !
#
# Label: 0
# Text: the #boston globe's full front page features an #ar15 rifle and three words: "make it stop"  #media #newspaper
#
# Label: 0
# Text: thank you @user for my new sho curly locks!!! i love my hair! #sho #tame #newme #fresh   #thankful ðð¼ðð
#
# Label: 0
# Text: Â©the snaparazziâ¢: #dorset #durdledoor #england #goodmorning #sea #landscape #beach #fun   #spring #summer
#
# Label: 0
# Text:  wheniamalone #alone  #lonely #noonecares ness #upsetting #dipressive #stay_strong  does anyone else...
#
# Label: 0
# Text: dalton's upcoming album will be freaking dope!! â¤ï¸â¤ï¸â¤ï¸â¤ï¸   #soproudofhim
#
# Label: 1
# Text: @user #allahsoil thereâs no such thing as an average christian, or muslim, or jew.  â¦  â¦
#
# Label: 0
# Text:  @user america is feasting on sensationalizing this tragedy it suppos it's greatest agenda islamic hate and lgbt suppo
#
# Label: 0
# Text:  @user g+t in hand watching wheeler dealers restore a jag mk 2 !! perfect   father's day #cheers
#
# Label: 0
# Text: oh yeah i found the perfect bihday cake for @user ððð    bihdaylivmorgan â¤ï¸
#
# Label: 0
# Text: @user @user life was fun while it lasted; any last werdz?  #sorry   #victim #accident
#
# Label: 0
# Text: you know you've reached a new low when the man who delivers your pizza knows your name   #ineedtoworkoutagain
#
# Label: 0
# Text: corrieeeeeee time!!!!!ð   @user
#
# Label: 0
# Text: feeling down, hate when things kick in like this. family is right, luv is just not within my grasps. after so long there bak #feelings  .
#
# Label: 0
# Text: he brings out the best in me #husband   #inlove
#
# Label: 0
# Text: and sometimes i just wanna be a pa of @user little family â¤ï¸ð #facebooklive   #summer #pool #aww #iwantthat
#
# Label: 0
# Text:   2nd #bihday to #westbridgford group of #athenanetwork #savvy #energised #suppoive #womeninbiz #proud
#
# Label: 0
# Text: a true, loving father will always be there for children when times get tough   father's day #nathancreations
#
# Label: 0
# Text: @user @user yes, and he did it for the least noble reasons too. and it backfired for him, so now we all have to suffer!
#
# Label: 0
# Text: road trip!   @user
#
# Label: 0
# Text:  @user @user all set for first @user @user #ballincollig  #cork #running
#
# Label: 0
# Text: twitter is a crazy place. nobody knows shit about #jocox's death &amp; yet everybody's giving their sick take on why and how it occurred...
#
# Label: 0
# Text: look at what's landed on my desk this morning ð  â¦
#
# Label: 0
# Text: the all-new #jaguarfpace on its way to #jaguarstb!   #comingsoon #jaguar #fpaceâ¦
#
# Label: 0
# Text:  @user lol... ask again no please
#
# Label: 0
# Text: #tattoosleeves   gorilla simulator: you need to do to adapt to the environment. the need to tear the city. m
#
# Label: 0
# Text: i am composed. #i_am #positive #affirmation
#
# Label: 0
# Text:  â #united kingdom boe asset purchase facility meets forecasts (Â£375b) in june   #blog #silver #gold #forex
#
# Label: 0
# Text: still waiting for word on the new house, vendor wanted overnight to consider offers #nervous   #needahouse
#
# Label: 1
# Text: like msian opposition and their claim that bangladeshis voted for bn. no evidence yet people believe it anywayâ¦
#
# Label: 0
# Text: @user will be a broken pay come late november! @user will be defeated after insane campaign &amp; @user will be blamed!
#
# Label: 0
# Text: #takemeanywhere got a speeding ticket trying to meet shia in stickney, sd. didn't get there in time.   day
#
# Label: 0
# Text: archetypal flame - happy father's day en   #father's #day #love #light #agape #dia #padre
#
# Label: 0
# Text: google has bn racist for ages...d world is just catching on...
#
# Label: 0
# Text: big night for #harnessracing !!!  michael's power is in tonight! @user   #goodluck ðð´â¤ï¸ðð´â¤ï¸
#
# Label: 0
# Text: amen   but true  man is the worst animal on eah
#
# Label: 1
# Text: @user #boycotttigerwoods. stop #normalizing @user  #antisemite #bigot
#
# Label: 0
# Text: sometimes i feel that i have given too much rights to others to take decision about my work that's why the are not responding to me...
#
# Label: 0
# Text: last night at the @user pa of our group was refused to be let in. they weren't drunk, but they were all black.
#
# Label: 0
# Text: #good #morning #awesome #people #music #love #announcement #share #super   this will beâ¦
#
# Label: 0
# Text: happiness is living in the moment... ð   ð
#
# Label: 0
# Text: shark week stas in 10 days!!!! #sharkweek   #lovesharks
#
# Label: 0
# Text: ð photo of the day! . . . . . . . . . .  .  #toptags days top.tags dayâ¦
#
# Label: 0
# Text: the title of my autobiography.
#
# Label: 0
# Text: spend quality time with this awesome guy and my sweet pet :) #blessed #loved
#
# Label: 1
# Text: #zionism is a form of  @user
#
# Label: 0
# ...
# Text: please don't forget to use the word ! that is what "binds" these men. we can never ignore or excuse thatâ¦
#
# Label: 0
# Text: #love   gorilla simulator: you need to do to adapt to the environment. the need to tear the city. material d
#
# Label: 0
# Text: so much   shit going on in the world... â¹ï¸. 50 people. geeesh!
#
# Label: 0
# Text: pa represents.  #proud ,   #filibuster live stream
#
# Label: 0
# Text: sta laughing! crying only makes you sad.   #laugh #cry   #distressed #anxious #change #mindset #depressed
#
# Label: 0
# Text: @user interviewed 3x by fbi and still able to buy assault rifles, sickening! just don't understand. #somethinghastochange #orlando
#
# Label: 0
# Text:  @user go hea her page and videos! @user #follow # #thongthursday #sexy   #girlsoftwitter #ngot
#
# Label: 0
# Text: oops  my doughnut came before my jam..  @user
#
# Label: 0
# Text: i did wear something for me really excited to be a song. #did #wear #really
#
# Label: 0
# Text: #summer #formentera #comounniÃ±o #bomba   #friday @ formentera beach
#
# Label: 0
# Text: hi @user we hear you're coming to mk  . where about a will you be?
#
# Label: 1
# Text: @user 'an unappetizing scam' :-) | women, we need to throw off the  shackles of #salad | #food #foodie |â¦
#
# Label: 0
# Text: so   to #share the #simple, #elegant #businesscards i #designed for gracious muse jewelry!
#
# Label: 0
# Text: one of my worship experiences today on father's day included 13 references to the holy as "father" and none as "mother" or "parent"
#
# Label: 0
# Text: final day in my front end web development class today @user  #thankfulthursday
#
# Label: 0
# Text: my early father's day gift.. i got both my son's with me for father's day...   #satisfiedâ¦
#
# Label: 0
# Text: happy greatful sunday folks! heva great day ð   #sunday #methodist #gerejamethodistâ¦
#
# Label: 0
# Text: when "brundlefly" is the only way you can think to describe your nose hair status to your wife.
#
# Label: 0
# Text: ð   the complete list of indian olympic medal winners
#
# Label: 0
# Text: @user @user @user @user thats the standard of our home minister.
#
# Label: 0
# Text:   #father's day to all the awesome fathers out there! with #love --rome business school
#
# Label: 0
# Text: on route to #royalascot praying the rain can hold off for the picnic at least today !!   #dayout
#
# Label: 0
# Text: happy daddy's day to all the fab dads out there #fathersday  fathersday
#
# Label: 1
# Text: that hammock just attempted #whitegenocide #lies #tinfoilhat #fakenews #altrightcards
#
# Label: 0
# Text:  @user it's off to watch the football game between #romania &amp; france! ðð #goromania
#
# Label: 0
# Text:  @user #tgif   #ff to my #gamedev #indiedev #indiegamedev #squad! @user @user @user @user @user
#
# Label: 0
# Text: i am unwavering. #i_am #positive #affirmation
#
# Label: 0
# Text: we're on the ferry!ð   @user
#
# Label: 0
# Text: @user there was plenty of chat about the biltong on the e match commentary  &amp;hungry
#
# Label: 0
# Text:   #fathers day from the #otherside #ghostasylum #ghosthunting #gopro #staup #scienceproject #paranormal #mit
#
# Label: 0
# Text: #coffee anyone?   #humpday #ladies #wednesdayisgeorgeday #georgeclooney #handsome #love â¤ï¸
#
# Label: 0
# Text: have you seen our latest designs? vote for your favorites:  #cactus #hug #cute   #green
#
# Label: 0
# Text: the view@user park   graduation
#
# Label: 0
# Text: bday entourage â¤â¤â¤ #love #instagood #me #itsmybihday #us #cute #follow #photooftheday  â¦
#
# Label: 0
# Text: i hate it when i see people rounding up other followers to back up their opinion about a tweet a tweeter. this to me is also #bullying
#
# Label: 0
# Text: got gem106fm on in the #office playing some great #tunes and i'm feeling very   it'sâ¦
#
# Label: 0
# Text:   #wednesday #all! hoping you enjoy your day with much,much tweet blissful #aum. logging out:wed 10:59am june 8 2016 eugina g. herrera
#
# Label: 0
# Text: summer ðð´ð   #love  #stylemen #style #stylenanda #styles #instastyle #stylefileâ¦
#
# Label: 0
# Text: some of the things i've been #working on for @user this week.   to see this #game come together!
#
# Label: 0
# Text: just bought tickets to take mum to see @user been her dream for 25 years to see them #conce
#
# Label: 0
# Text:  @user for those of us who lost our wonderful dads too soon, this hard day is almost over. ð  #fathersday
#
# Label: 0
# Text: one year ð #june #summer #hot #hair #follow #me #followme #hastag #smile   #blue #eyesâ¦
#
# Label: 0
# Text: top 10 food items a   seasonal affective disorder patient must avoid #peh #busselton #hoba #wellington
#
# Label: 0
# Text: loving the sun today! #summer #sunny #garden #sunbathing   #chilling #relaxing
#
# Label: 0
# Text:  @user the all-new #jaguarfpace on its way to #jaguarstb!   #comingsoon #jaguar #fpace
#
# Label: 0
# Text: after spending a week in bed #sick, i finally get to leave the house. que #energyoverload!
#
# Label: 0
# Text:  @user "today is here" -everyone going to blast
#
# Label: 0
# Text: @user shit i just realized your account isn't a month old. it's only a few weeks old. that's more like 110 tweets a day. just
#
# Label: 0
# Text:  @user @ my call back!  #casting #castingcall #model #cute #toddler #toddlerlife #photooftheday #nofilter #family   httâ¦
#
# Label: 0
# Text: just got done watching 13 hrs. man what did we do to our people.  #shameful we need #trump now. @user our gov. is pathetic.
#
# Label: 0
# Text:   fathers special dai# congroutz 4 al fatherz##
#
# Label: 0
# Text: traveling happy #family   holidays #car #sunnyday #sunny #sunday #glasses #enjoyâ¦
#
# Label: 0
# Text:   #humpday  enjoy my newest act simply titled "stripper" i filmed this yesterday to applyâ¦
#
# Label: 0
# Text:  @user #nohwestern researchers say #chronicpain rewires pas of the #brain that make us #happy or  .
#
# Label: 0
# Text: smoking a black in an eno ðº
#
# Label: 0
# Text:  @user   #wednesday! questions or #biking needs/wants? check out our page!
#
# Label: 0
# Text:  @user dust   #piano by gummy beatz.   #beats
#
# Label: 1
# Text: #us refuses to veto resolution on #israel  #zionism #illegalsettlements
#
# Label: 1
# Text: @user #allahsoil we should not conflate islamic extremism with terrorism    #emiratis #2016in4â¦
#
# Label: 1
# Text: see what #russia is doing in #syria,  destroying masjids
#
# Label: 0
# Text: now playing  :  philip aaberg - " elegy" on    #melancholy   #melancholymusic
#
# Label: 0
# Text: i want some cereal &amp; ain't tryna get up ð
#
# Label: 0
# Text: um escue me but, where is deez animals? @user @user #wheredapuppjes #ciymove
#
# Label: 0
# Text: when your house is full of people and all you want to do is lock yourself in your room.    #depression
#
# Label: 0
# Text: apparently the nba is now the new wwe! tim donaghy: nba suspended green to prolong finals  via @user #mindblown
#
# Label: 0
# Text: thank you for following @user it's nice to meet you. ð·#friends   tuesday ð
#
# Label: 0
# Text: what is the world coming to? are massacres going to be a way of life?
#
# Label: 0
# Text:  @user *big annoucement* you will be able to play as #prompto on #psvr #finalfantastyxv #sonye3 #gameate3
#
# Label: 0
# Text: sunday funday!! ðð»âð   #smile  #happiness #love
#
# Label: 0
# Text:  @user my beautiful princess mummy #muma #bestfriend #beaut #smiley
#
# Label: 0
# Text: all stocked up waiting now for lowery and dermot to bring this one home   days #good luck lads
#
# Label: 0
# Text: @user when will we be able to sta making up the audience??
#
# Label: 0
# Text: @user thank you! i put up another video after its done! but we're remodeling the whole house!
#
# Label: 0
# Text: early evening sunshine at the @user summer garden pay tonight, including some rather cool music
#
# Label: 0
# Text: today is #flipflopday. so add flipflops to your casual clothes today and be happy #summer
#
# Label: 0
# Text: please like &amp; share if you are agree  #dna #dnaquotes #quote #quoteoftheday #love   #proverb #lifestyle...
#
# Label: 1
# Text: come on n wake the eff up usa! this is craziness. does it all stem from  n hatred of #obama ? it seems likeâ¦
#
# Label: 0
# Text: we spent #familytime by doing simple wefie, we're   #latepost #melawanarus untukâ¦
#
# Label: 0
# Text: mass shooting in us = grp calling to ban guns. grp defending guns. gun comp stocks soar. victims become side note.   #orlandounited
#
# Label: 0
# Text:  episode 1 of our vlog is now live!!!   #interrailing #london to #amsterdam #britishguy #austriangirl #blonde
#
# Label: 0
# Text: 100 amazing health benefits of cucumbers!    #healthy is  !!  #doplants!
#
# Label: 0
# Text: #mirrorofthewitch ep9 time!!!   ððð
#
# Label: 0
# Text:  @user i am thankful for inspiration. #thankful #positive
#
# Label: 0
# Text: feels good to know god's grace and mercy are infiniteâ¢   tho #chapelflow
#
# Label: 0
# Text: i will be so angry with arsenal if city sign #aubameyang for the money which we could afford   #arsenal #afc ð¤ð¤
#
# Label: 1
# Text: dr. frances cress welsing - racism defined #whitesupremacy  #drfranciscresswelsing
#
# Label: 0
# Text: get high and leave everything else behind ð¸ #good #night #havefun   #drink #love #peaceâ¦
#
# Label: 0
# Text: yumy yumy. ð° three milks cake (toa tres leches) made by my ðª    #cake #desseâ¦
#
# Label: 0
# Text: ð   #tech 7 bitcoin postcards you can send to your fellow bitcoiners
#
# Label: 0
# Text: #girliguessimwithdeath lets get this trending
#
# Label: 0
# Text: great day editing my first block. watching all the great work everyone did back is a joy   #wow
#
# Label: 0
# Text: how stupid are the russians and english fans killing each other for a 1-1 game ! please grow up #euro2016
#
# Label: 0
# Text: sunday night. ðªð#goals   tomorrow's a new day new goals .ððð
#
# Label: 1
# Text: @user the end of   #me #selfie # #love #messi #cr7 #religion #christianity #mecca_live
#
# Label: 0
# Text:   #father's #day to all that deserve to be #call a #dad even if it's a #woman. #god #blessâ¦
#
# Label: 0
# Text: last one ðð . appletstag #lastone #ipromise #selfie #sorrynotsorry #fun #nofilter #summer  â¦
#
# Label: 0
# Text: i will always remember #dl2016 for the day we got engaged @user   #download #downloadfestival
#
# Label: 1
# Text: @user @user  nothing. that would be .  #taharrush #taharrushgamea #rapeugee
#
# Label: 0
# Text: #model   i love u take with u all the time in urð±!!! ððððð¦ð¦ð¦
#
# Label: 0
# Text:  @user i love you for this ð¹ð¹ðð¾
#
# Label: 0
# Text:  !!!! new @user #showerdec on its way for installation next week!!! looking forward to fitting it! #teamcontour
#
# Label: 0
# Text: @user love that your statements came from the man who was rebuked by voters in 2008.   #goodluckinnovember #loser
#
# Label: 0
# Text: if dudes wana fuck eachother n get married, i can never be mad at tht. jus means more females for me! #damn50 #orlando # #omg50 #gay
#
# Label: 0
# Text: steak night at work means a night off training, shandy, tv, chocolate and knitting.  â¦
#
# Label: 0
# Text: @user @user not a brown-noser?? you're practically making out with hillary in your profile pictureðð¼ð©
#
# Label: 0
# Text:  .... because i choose to be.
#
# Label: 1
# Text: i couldn't end #2016 without mentioning #trump.  #feminism #photographs #shockfactor
#
# Label: 0
# Text: #chateaubriand #stovells absolutely lovely #food #yum
#
# Label: 0
# Text:  @user #frarou woohoo! #euro2016 kicks off..!
#
# Label: 0
# Text: and here i thought @user  and i were having a lovely conversation. i guess he only debates with people he agrees with.
#
# Label: 0
# Text: happy tuesday!! feeling fantastic today. looking forward to tonight's workout. #smile  â¦
#
# Label: 0
# Text: i feel horrible just watching my brother being sick
#
# Label: 0
# Text: what the hell is wrong with humanity? why would anyone need to do anything to prove his faith?#ridiculous
#
# Label: 0
# Text: lily's current outfit of choice ð #baby #lily #fluffysocks #dressup #butterfly #backpack  â¦
#
# Label: 0
# Text: love this clickðð #exclusive pic of @user  on #ssk #set #handsome #hot #dashing #smile   @user
#
# Label: 0
# Text:   friday everyone ðð #morning #fridayfeeling #love #kind #behappy
#
# Label: 0
# Text: i love my friends! happy sunday funday everyone!   #sunday #funday #friends #squad #goofballs
#
# Label: 0
# Text: #hea is the easiest thing which can be #fooled,  i am  , i am #sad and it just takes a thought to be anywhere in btw them ð
#
# Label: 0
# Text:  @user when bae is at work and can't text you and you have no one to talk to.
#
# Label: 0
# Text: what an afternoon! ðð
#
# Label: 1
# Text: a follow up from the gentlemen who were kicked off of @user airlines for simply speaking arabic
#
# Label: 0
# Text: #8aÃ±olevyrrroni @user  @user #levyrroni #recuerdos memories... ð­â¤ð«ð #recuerdos   #friends #life
#
# Label: 0
# Text: my hea is perfect because you are inside ð  #love #loveforever #couple   #gratefulâ¦
#
# Label: 1
# Text: did  keep #colinpowell and #condoleezzarice from being #secretaryofstate? words not to use in #2017 . #jumpedtheshark
#
# Label: 1
# Text: @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user
#
# Label: 0
# Text: @user i c sociopaths low iq satanic everything that is an abomination2 god will b the norm as well as committing a1 felonies
#
# Label: 0
# Text: @user thanks gemma
#
# Label: 1
# Text: @user judd is a  &amp; #homophobic #freemilo #milo #freemilo #milo #freemilo #milo #freemilo #milo #freemilo
#
# Label: 1
# Text: lady banned from kentucky mall. @user  #jcpenny #kentucky
#
# Label: 0
# Text: ugh i'm trying to enjoy my happy hour drink &amp; there is talks of politics in the bar can we guess what they are discussing ugh!!   hour
#
# Label: 0
# Text: want to know how to live a   life? do more things that make you happy and less things that make you unhappy! it's that simple!
#
# Label: 0
# Text: love island ð
#
# Label: 0
# Text: my fav actor #vijaysethupathi ! my fav actress @user ! my most fav director @user !! one film !! can't wait   :)
#
# Label: 0
# Text: whew  ð it's a productive and   #friday!!!
#
# Label: 0
# Text: @user she's finally here! @user
#
# Label: 0
# Text: passed first year of uni #yay #love #pass #unistudent #photographystudent #ucs #soproud
#
# Label: 0
# Text: this week is flying by   #humpday - #wednesday #kamp #ucsdâ¦
#
# Label: 0
# Text:  @user modeling photoshoot this friday yay #model #me #follow #emo
#
# Label: 0
# Text: you're surrounded by people who love you (even more than you deserve) and yet, why are so hateful?
#
# Label: 0
# Text: feel like... ðð¶ð #dog #summer #hot #help #sun #day   #more
#
# Label: 1
# Text: @user omfg i'm offended! i'm a  mailbox and i'm proud! #mailboxpride  #liberalisme
#
# Label: 1
# Text: @user @user you don't have the balls to hashtag me as a  but you say i am to weasel away.. lumpy tony.. dipshit.
#
# Label: 1
# Text:  makes you ask yourself, who am i? then am i anybody? until ....god . oh thank you god!
#
# Label: 0
# Text: hear one of my new songs! don't go - katie ellie #youtube #original #music #song #relationship #songwriter
#
# Label: 0
# Text:  @user you can try to 'tail' us to stop, 'butt' we're just having too good of a time!  #goldenretriever   #animals
#
# Label: 0
# Text: i've just posted a new blog: #secondlife #lonely #neko
#
# Label: 0
# Text: @user you went too far with @user
#
# Label: 0
# Text: good morning #instagram #shower #water #berlin #berlincitygirl   #girl #newyork #zÃ¼rich #genf #bern
#
# Label: 0
# Text: #holiday   bull up: you will dominate your bull and you will direct it whatever you want it to do. when you
#
# Label: 0
# Text: less than 2 weeks ððð¼ð¹ððµ @user #ibiza#bringiton#mallorca#holidays#summer
#
# Label: 0
# Text: off fishing tomorrow @user carnt wait first time in 2 years
#
# Label: 0
# Text: ate @user isz that youuu?ðððððððððâ¤ï¸
#
# Label: 0
# Text:   to see nina turner on the airwaves trying to wrap herself in the mantle of a genuine hero like shirley chisolm. #shame #imwithher
#
# Label: 0
# Text: listening to sad songs on a monday morning otw to work is sad
#
# Label: 1
# Text: @user #sikh #temple vandalised in in #calgary, #wso condemns  act
#
# Label: 0
# Text: thank you @user for you follow

# %%
# prompt: Preprocess the above text data to suit the requirements of BERT (like tokenization, adding special tokens, attention masks).

from transformers import BertTokenizer

# Load the BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Check the column names in your DataFrame
print(df.columns)

# Replace 'text' with the actual name of the column containing the text data
# For example, if the column name is 'tweet', use:
tokens = tokenizer(df['tweet'].tolist(), truncation=True, padding=True, return_tensors='pt')

# Extract input_ids, attention_mask, and token_type_ids
input_ids = tokens['input_ids']
attention_mask = tokens['attention_mask']
token_type_ids = tokens['token_type_ids']
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Index(['id', 'label', 'tweet'], dtype='object')

# %%
# prompt: Model Building: Leverage the pre-trained BERT model from Hugging Face and add classification (positive , negative and neutral) layers on top.

import torch.nn as nn
from transformers import BertModel

class SentimentClassifier(nn.Module):
  def __init__(self, num_classes=3):  # 3 classes: positive, negative, neutral
    super(SentimentClassifier, self).__init__()
    self.bert = BertModel.from_pretrained('bert-base-uncased')
    self.dropout = nn.Dropout(0.1)
    self.out = nn.Linear(self.bert.config.hidden_size, num_classes)

  def forward(self, input_ids, attention_mask, token_type_ids):
    _, pooled_output = self.bert(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids=token_type_ids,
        return_dict=False
    )
    output = self.dropout(pooled_output)
    return self.out(output)

# Initialize the model
model = SentimentClassifier()

# %%
# prompt: Training: Fine-tune the BERT model on your dataset, carefully tuning the learning rate and other hyperparameters.

import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Assuming 'label' is the column name for sentiment labels (0: negative, 1: neutral, 2: positive)
# Ensure labels is the correct length, the same as the first dimension of the tokenized data
labels = torch.tensor(df['label'].values[:input_ids.shape[0]])

# Create a TensorDataset
dataset = TensorDataset(input_ids, attention_mask, token_type_ids, labels)

# Split into training and validation sets (adjust split ratio as needed)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=2e-5)  # Adjust learning rate as needed

# Training loop
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

num_epochs = 3  # Adjust as needed
for epoch in range(num_epochs):
  model.train()
  train_loss = 0
  for batch in train_loader:
    input_ids, attention_mask, token_type_ids, labels = batch
    input_ids, attention_mask, token_type_ids, labels = input_ids.to(device), attention_mask.to(device), token_type_ids.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = model(input_ids, attention_mask, token_type_ids)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()

  # Validation loop
  model.eval()
  val_loss = 0
  with torch.no_grad():
    for batch in val_loader:
      input_ids, attention_mask, token_type_ids, labels = batch
      input_ids, attention_mask, token_type_ids, labels = input_ids.to(device), attention_mask.to(device), token_type_ids.to(device), labels.to(device)

      outputs = model(input_ids, attention_mask, token_type_ids)
      loss = criterion(outputs, labels)
      val_loss += loss.item()

  print(f"Epoch {epoch+1}/{num_epochs}: Train Loss: {train_loss/len(train_loader)}, Val Loss: {val_loss/len(val_loader)}")
# Out:
# Epoch 1/3: Train Loss: 0.7365532517433167, Val Loss: 0.7001771330833435
# Epoch 2/3: Train Loss: 0.6024259924888611, Val Loss: 0.670009970664978
# Epoch 3/3: Train Loss: 0.5666627585887909, Val Loss: 0.5977081060409546

# %%
# prompt: Evaluation: Use metrics like accuracy, precision, recall, and F1-score to evaluate the above  model's performance.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Evaluation loop
model.eval()
all_predictions = []
all_labels = []
with torch.no_grad():
  for batch in val_loader:
    input_ids, attention_mask, token_type_ids, labels = batch
    input_ids, attention_mask, token_type_ids, labels = input_ids.to(device), attention_mask.to(device), token_type_ids.to(device), labels.to(device)

    outputs = model(input_ids, attention_mask, token_type_ids)
    _, predictions = torch.max(outputs, dim=1)
    all_predictions.extend(predictions.cpu().numpy())
    all_labels.extend(labels.cpu().numpy())

# Calculate metrics
accuracy = accuracy_score(all_labels, all_predictions)
precision = precision_score(all_labels, all_predictions, average='weighted')  # Use 'weighted' for multi-class
recall = recall_score(all_labels, all_predictions, average='weighted')
f1 = f1_score(all_labels, all_predictions, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# Accuracy: 0.8571428571428571
# Precision: 0.7346938775510203
# Recall: 0.8571428571428571
# F1-score: 0.7912087912087912
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Sentiment Analysis using BERT on Twitter Data
#
# ### 1. Introduction
#
# This project aims to perform sentiment analysis on a Twitter dataset using the BERT (Bidirectional Encoder Representations from Transformers) model. Sentiment analysis is a natural language processing (NLP) task that involves classifying text into different sentiment categories, such as positive, negative, or neutral. BERT, a state-of-the-art language representation model, is employed to capture the contextual information and semantic nuances in the tweets.
#
# ### 2. Data Preprocessing
#
# The Twitter dataset, assumed to be stored in a CSV file on Google Drive, is loaded using Pandas. The following preprocessing steps are performed:
#
# - **Loading Data:** The CSV file is read into a Pandas DataFrame.
# - **Tokenization:** The BERT tokenizer is used to convert the text data into numerical tokens that can be processed by the model. The `truncation` and `padding` arguments ensure that all sequences have the same length.
# - **Label Extraction:** The sentiment labels (assumed to be in a column named 'label') are extracted and converted into a PyTorch tensor.
#
# ### 3. Model Architecture
#
# A custom sentiment classifier is built using PyTorch, leveraging the pre-trained BERT model as the base. The architecture consists of:
#
# - **BERT Layer:** The pre-trained BERT model extracts contextualized embeddings from the input tokens.
# - **Dropout Layer:** A dropout layer with a probability of 0.1 is added to prevent overfitting.
# - **Linear Layer:** A fully connected linear layer maps the BERT embeddings to the number of sentiment classes (3 in this case).
#
# ### 4. Training and Evaluation
#
# The model is trained using the AdamW optimizer and cross-entropy loss function. The dataset is split into training and validation sets, and the model is trained for a specified number of epochs. During training, the model learns to adjust its parameters to minimize the loss and improve its ability to predict sentiment labels.
#
# After training, the model is evaluated on the validation set using metrics such as accuracy, precision, recall, and F1-score. These metrics provide insights into the model's performance in classifying the sentiment of tweets.
#
# ### 5. Challenges and Insights
#
# - **Data Imbalance:** If the dataset has an uneven distribution of sentiment categories, techniques like oversampling or undersampling might be needed to address the imbalance.
# - **Hyperparameter Tuning:** The learning rate, batch size, and number of epochs can significantly impact the model's performance. Experimentation is required to find optimal values.
# - **Contextual Understanding:** BERT's ability to capture contextual information is crucial for sentiment analysis, as the meaning of words can change depending on the surrounding text.
#
# ### 6. Conclusion
#
# This project demonstrates the use of BERT for sentiment analysis on Twitter data. The model's performance is evaluated using various metrics, providing a quantitative assessment of its ability to classify sentiment. Further improvements can be explored by addressing challenges like data imbalance and fine-tuning hyperparameters.
